# %%
import glob
import re
import numpy as np
import pandas as pd
import clima_anom as ca
from netCDF4 import Dataset

import matplotlib.pyplot as plt

import matplotlib.cbook
import matplotlib.gridspec as gridspec

import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
season = 'summer'

# %%
list_files = glob.glob('/mnt/Data/Data/IMERG/Daily_01x01/'+season+'/IMERG*.nc')
list_files = sorted(list_files)
len_files = len(list_files)

# %%
pre_mean = np.zeros([len_files,750,600])
for t in range(len_files):
    tmp = ca.read_netcdf(list_files[t],0)
    if t == 0:
        lat = tmp['lat']
        lon = tmp['lon']
    pre_mean[t,:,:] = np.mean(tmp['prec'],axis=0)

# %%
pre_mean_serie = np.zeros(62)
for t in range(62):
    pre_mean_serie[t] = np.mean(pre_mean[t,:,:])

# %%
plt.plot(pre_mean_serie)
