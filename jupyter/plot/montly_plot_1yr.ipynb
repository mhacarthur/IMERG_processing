# %%
import os
import glob
import numpy as np
import clima_anom as ca
import matplotlib.pyplot as plt
import matplotlib.cbook
import matplotlib.gridspec as gridspec
import cartopy
import cartopy.crs as ccrs

# %%
yy = '2001'

# %%
pre_dir = '/media/arturo/Arturo/Data/IMERG/raw_1dy/*_'+yy+'*.nc'
pre_list = glob.glob(pre_dir)
pre_list = sorted(pre_list)
len_list = len(pre_list)
print(pre_dir)
print(len_list)
# Out:
# /media/arturo/Arturo/Data/IMERG/raw_1dy/*_2001*.nc
# 365

# %%
list_01 = []
list_02 = []
list_03 = []
list_04 = []
list_05 = []
list_06 = []
list_07 = []
list_08 = []
list_09 = []
list_10 = []
list_11 = []
list_12 = []

for t in range(len_list):
    namefile = pre_list[t].split('/')[-1].split('_')[1].split('-')[0]
    year = namefile[0:4]
    month = namefile[4:6]

    if year == yy and month == '01':
        list_01.append(pre_list[t])

    elif year == yy and month == '02':
        list_02.append(pre_list[t])

    elif year == yy and month == '03':
        list_03.append(pre_list[t])

    elif year == yy and month == '04':
        list_04.append(pre_list[t])

    elif year == yy and month == '05':
        list_05.append(pre_list[t])

    elif year == yy and month == '06':
        list_06.append(pre_list[t])

    elif year == yy and month == '07':
        list_07.append(pre_list[t])

    elif year == yy and month == '08':
        list_08.append(pre_list[t])

    elif year == yy and month == '09':
        list_09.append(pre_list[t])

    elif year == yy and month == '10':
        list_10.append(pre_list[t])

    elif year == yy and month == '11':
        list_11.append(pre_list[t])

    elif year == yy and month == '12':
        list_12.append(pre_list[t])

# %%
tmp = ca.read_netcdf(list_01[0],2)
lat = tmp["lat"]
lon = tmp["lon"]

nlat = len(lat)
nlon = len(lon)

lon2d, lat2d = np.meshgrid(lon, lat)

print('Lat:',lat.shape)
print('Lon:',lon.shape)
# Out:
# precipitationCal : (1, 550, 601)
# lat : (601,)
# lon : (550,)
# time : (1,)
# Lat: (601,)
# Lon: (550,)

# %%
pr01 = np.zeros([len(list_01),nlat,nlon])
for nn in range(len(list_01)):
    data = ca.read_netcdf(list_01[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr01[nn,:,:] = prec

pr02 = np.zeros([len(list_02),nlat,nlon])
for nn in range(len(list_02)):
    data = ca.read_netcdf(list_02[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr02[nn,:,:] = prec

pr03 = np.zeros([len(list_03),nlat,nlon])
for nn in range(len(list_03)):
    data = ca.read_netcdf(list_03[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr03[nn,:,:] = prec

pr04 = np.zeros([len(list_04),nlat,nlon])
for nn in range(len(list_04)):
    data = ca.read_netcdf(list_04[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr04[nn,:,:] = prec

pr05 = np.zeros([len(list_05),nlat,nlon])
for nn in range(len(list_05)):
    data = ca.read_netcdf(list_05[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr05[nn,:,:] = prec

pr06 = np.zeros([len(list_06),nlat,nlon])
for nn in range(len(list_06)):
    data = ca.read_netcdf(list_06[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr06[nn,:,:] = prec

pr07 = np.zeros([len(list_07),nlat,nlon])
for nn in range(len(list_07)):
    data = ca.read_netcdf(list_07[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr07[nn,:,:] = prec

pr08 = np.zeros([len(list_08),nlat,nlon])
for nn in range(len(list_08)):
    data = ca.read_netcdf(list_08[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr08[nn,:,:] = prec

pr09 = np.zeros([len(list_09),nlat,nlon])
for nn in range(len(list_09)):
    data = ca.read_netcdf(list_09[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr09[nn,:,:] = prec

pr10 = np.zeros([len(list_10),nlat,nlon])
for nn in range(len(list_10)):
    data = ca.read_netcdf(list_10[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr10[nn,:,:] = prec

pr11 = np.zeros([len(list_11),nlat,nlon])
for nn in range(len(list_11)):
    data = ca.read_netcdf(list_11[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr11[nn,:,:] = prec

pr12 = np.zeros([len(list_12),nlat,nlon])
for nn in range(len(list_12)):
    data = ca.read_netcdf(list_12[nn],0)
    prec = np.array(data["precipitationCal"])[0,:,:].T
    prec[prec<=0]=0
    pr12[nn,:,:] = prec

# %%
pr_mean = np.zeros([12,nlat,nlon])
pr_mean[0,:,:] = np.mean(pr01,axis=0)
pr_mean[1,:,:] = np.mean(pr02,axis=0)
pr_mean[2,:,:] = np.mean(pr03,axis=0)
pr_mean[3,:,:] = np.mean(pr04,axis=0)
pr_mean[4,:,:] = np.mean(pr05,axis=0)
pr_mean[5,:,:] = np.mean(pr06,axis=0)
pr_mean[6,:,:] = np.mean(pr07,axis=0)
pr_mean[7,:,:] = np.mean(pr08,axis=0)
pr_mean[8,:,:] = np.mean(pr09,axis=0)
pr_mean[9,:,:] = np.mean(pr10,axis=0)
pr_mean[10,:,:] = np.mean(pr11,axis=0)
pr_mean[11,:,:] = np.mean(pr12,axis=0)

# %%
list_month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
linewidth_shape = 0.2
levels = np.arange(0,60,4)

proj = ccrs.PlateCarree()
cmap = plt.cm.Spectral_r
# cmap = plt.cm.YlGnBu

fig = plt.figure(figsize=(10,8),dpi=200)
gs = gridspec.GridSpec(3,4)

a = 0
for row in range(3):
    for col in range(4):
        ax1 = plt.subplot(gs[row, col], projection = proj)
        ax1.coastlines(linestyle='-',linewidth=0.1,color='black',zorder=4)
        a1 = ax1.contourf(lon2d, lat2d,pr_mean[a,:,:],levels = levels, cmap=cmap,extend='max')
        ax1.text(0.1, 0.25, list_month[a], va='bottom', ha='center',rotation_mode='anchor',
        transform=ax1.transAxes)

        # plt.colorbar(a1)

        if a == 0:
            ax1.set_title('GPM IMERG L3',fontsize=8,loc='left')
            ax1.set_title('Daily',fontsize=8,loc='right')

        elif a == 3:
            ax1.set_title('Year: '+yy,fontsize=8,loc='right')

        if col == 0:
            gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='k',alpha=0.1,linestyle='--')
            gl.top_labels = False
            gl.bottom_labels = False
            gl.left_labels = True
            gl.right_labels = False
            gl.xlabel_style = {'size': 6, 'color': 'k'}
            gl.ylabel_style = {'size': 6, 'color': 'k'}

        if row == 2:
            gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='k',alpha=0.1,linestyle='--')
            gl.top_labels = False
            gl.bottom_labels = True
            gl.left_labels = False
            gl.right_labels = False
            gl.xlabel_style = {'size': 6, 'color': 'k'}
            gl.ylabel_style = {'size': 6, 'color': 'k'}

        else:
            gl = ax1.gridlines(crs=proj,draw_labels=True,linewidth=0.2,color='k',alpha=0.1,linestyle='--')
            gl.top_labels = False
            gl.bottom_labels = False
            gl.left_labels = False
            gl.right_labels = False
            gl.xlabel_style = {'size': 6, 'color': 'k'}
            gl.ylabel_style = {'size': 6, 'color': 'k'}    

        a = a + 1

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, hspace=0.05, wspace=0.05)

cbaxes = fig.add_axes([0.127, 0.06, 0.772, 0.04])
fig.colorbar(a1, cax = cbaxes,orientation="horizontal")

salida = '../../images/IMERG_'+year+'_Monthly_Seasonal.png'
print(salida)
plt.savefig(salida,facecolor='white',bbox_inches ='tight',pad_inches = 0.1)
# Out:
# ../images/IMERG_2001_Monthly_Seasonal.png
