# %%
import os
import glob
import subprocess

# %%
dir_base = os.path.join('/','home','arturo','Downloads','IMERG_SA')

# %%
file_grid = os.path.join(dir_base, 'mrigridGLM_05x05_SA')
order = f"remapbil,{file_grid}"
print(f'Grid File: {file_grid}')

file_input = os.path.join(dir_base, 'IMERG_SA_final_1dy_2000_01_01_2024_12_31.nc')
print(f'Input file: {file_input}')

file_output = os.path.join(dir_base, 'IMERG_SA_final_1dy_2000_01_01_2024_12_31_05x05.nc')
print(f'Input file: {file_output}')
# Out:
# Grid File: /home/arturo/Downloads/IMERG_SA/mrigridGLM_05x05_SA
# Input file: /home/arturo/Downloads/IMERG_SA/IMERG_SA_final_1dy_2000_01_01_2024_12_31.nc
# Input file: /home/arturo/Downloads/IMERG_SA/IMERG_SA_final_1dy_2000_01_01_2024_12_31_05x05.nc

# %%
subprocess.run(["cdo", order, file_input, file_output])
# Out:
# cdo    remapbil: Bilinear weights from lonlat (511x581) to lonlat (110x120) grid
# CompletedProcess(args=['cdo', 'remapbil,/home/arturo/Downloads/IMERG_SA/mrigridGLM_05x05_SA', '/home/arturo/Downloads/IMERG_SA/IMERG_SA_final_1dy_2000_01_01_2024_12_31.nc', '/home/arturo/Downloads/IMERG_SA/IMERG_SA_final_1dy_2000_01_01_2024_12_31_05x05.nc'], returncode=0)
